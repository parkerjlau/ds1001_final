# %% [markdown]
# # Final Project Notebook
#
# Use the follow cells prompts to complete the final project for the course. Everything you need should be present in this notebook or previous notebooks we've used in class. You can work together as needed.
#
#  - You will need to name your own dataset and use that name throughout
#  - There are sections where you need to make changes the code and insert new code this will be noted in the code provided
#  - You may get frustrated along the way, this is totally normal, just remember even small changes to the code make a huge difference.

# %% [markdown]
# ## Question Fork the Repository
# i. Include a screenshot of the forked repo in your GitHub account
#
# To fork the repository:
# 1. Go to https://github.com/NovaVolunteer/ds1001_final
# 2. Click the "Fork" button in the top right corner
# 3. The repo will be forked to your GitHub account
# 4. Take a screenshot of your forked repository

# %% [markdown]
# ### You should now be able to open your cloned repo in google collab, use the code below.
#
# ### It's very helpful to have the variable inspector open while you go through this process. To do so go to tools>command palette>show variable inspector
#
# ### It's also helpful to open up the folder tree on the left menu bar. Just click on the folder icon and then the ds1001_final folder. The data is located in the data folder in the processed sub-folder.

# %%
# !git clone "https://github.com/username/repository.git"
# This script clones a GitHub repository using Git command line tool. 
# Insert the path to your desired repository in place of the URL.

# %% [markdown]
# ## Systems

# %%
# Activate the finalproj environment
# !source ds1001_final/ds1001_final/finalproj/bin/activate
# Out:
# /bin/bash: line 1: ds1001_final/ds1001_final/finalproj/bin/activate: No such file or directory

# %%
### You can use this command to list all the packages in your environment
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# comm                    0.2.3
# debugpy                 1.8.20
# decorator               5.2.1
# executing               2.2.1
# ipykernel               7.2.0
# ipython                 9.13.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.8.0
# jupyter_core            5.9.1
# matplotlib-inline       0.2.1
# nest-asyncio            1.6.0
# packaging               26.2
# parso                   0.8.6
# pexpect                 4.9.0
# pip                     23.2.1
# platformdirs            4.9.6
# prompt_toolkit          3.0.52
# psutil                  7.2.2
# ptyprocess              0.7.0
# pure_eval               0.2.3
# Pygments                2.20.0
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.5.5
# traitlets               5.14.3
# wcwidth                 0.6.0
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install "XX"

#You'll likely need to install the fairlearn packages, if not already installed.
#Are there additional packages to install? (Cross check with the list above to 
# ensure all packages are installed)
# Out:
# Collecting XX
#   Obtaining dependency information for XX from https://files.pythonhosted.org/packages/f0/e2/bbe4054a1ff69de0dd90a487629849ea620bbbfa9b8f9a55c2b301087365/XX-3.3.2-py3-none-any.whl.metadata
#   Downloading XX-3.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting scrapy (from XX)
#   Obtaining dependency information for scrapy from https://files.pythonhosted.org/packages/32/2c/b9d926e117765d84654efb5a8280379e76a681338155c5c79578b4b207ac/scrapy-2.15.2-py3-none-any.whl.metadata
#   Downloading scrapy-2.15.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting scrapyd (from XX)
#   Obtaining dependency information for scrapyd from https://files.pythonhosted.org/packages/ae/87/4cbe01f175f37acdc1a428f5cda61cef2de3ef6f8c6892a429b8ef94f612/scrapyd-1.6.0-py3-none-any.whl.metadata
#   Downloading scrapyd-1.6.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting scrapyd-client (from XX)
#   Obtaining dependency information for scrapyd-client from https://files.pythonhosted.org/packages/40/55/70ec82b834880097c303da641e03b818c3b363d6be8d7c751fe93be3b3cd/scrapyd_client-2.0.3-py3-none-any.whl.metadata
#   Downloading scrapyd_client-2.0.3-py3-none-any.whl.metadata (11 kB)
# Collecting scrapy-redis (from XX)
#   Obtaining dependency information for scrapy-redis from https://files.pythonhosted.org/packages/82/d1/6ff55616d376d9a9f88ff2329838928bb5041773131251d70e310fc39e1d/scrapy_redis-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading scrapy_redis-0.9.1-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pyquery (from XX)
#   Obtaining dependency information for pyquery from https://files.pythonhosted.org/packages/76/f5/5067b48012967ea166b9bd0a015b69e0560e4c6e7c06f28d9bab8f9dd10b/pyquery-2.0.1-py3-none-any.whl.metadata
#   Downloading pyquery-2.0.1-py3-none-any.whl.metadata (9.0 kB)
# Collecting redis (from XX)
#   Obtaining dependency information for redis from https://files.pythonhosted.org/packages/74/3a/95deec7db1eb53979973ebd156f3369a72732208d1391cd2e5d127062a32/redis-7.4.0-py3-none-any.whl.metadata
#   Downloading redis-7.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting requests (from XX)
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/d7/8e/7540e8a2036f79a125c1d2ebadf69ed7901608859186c856fa0388ef4197/requests-2.33.1-py3-none-any.whl.metadata
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting pymysql (from XX)
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/7c/4c/ad33b92b9864cbde84f259d5df035a6447f91891f5be77788e2a3892bce3/pymysql-1.1.2-py3-none-any.whl.metadata
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting sqlalchemy (from XX)
#   Obtaining dependency information for sqlalchemy from https://files.pythonhosted.org/packages/2c/fa/65fcae2ed62f84ab72cf89536c7c3217a156e71a2c111b1305ab6f0690e2/sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting logzero (from XX)
#   Obtaining dependency information for logzero from https://files.pythonhosted.org/packages/b3/68/aa714515d65090fcbcc9a1f3debd5a644b14aad11e59238f42f00bd4b298/logzero-1.7.0-py2.py3-none-any.whl.metadata
#   Downloading logzero-1.7.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting happybase (from XX)
#   Obtaining dependency information for happybase from https://files.pythonhosted.org/packages/d9/13/a575170547d829b0e66fdeaac07264ad87347128a417211fc66ac2448195/happybase-1.3.0-py2.py3-none-any.whl.metadata
#   Downloading happybase-1.3.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting tld (from XX)
#   Obtaining dependency information for tld from https://files.pythonhosted.org/packages/9e/90/39a85a4b63c84213e78b3c17d22e1bf45328acf8ebb33ef93be30d0a3911/tld-0.13.2-py2.py3-none-any.whl.metadata
#   Downloading tld-0.13.2-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six in /workspaces/ds1001_final/ParkerLau_env/lib/python3.12/site-packages (from happybase->XX) (1.17.0)
# Collecting thriftpy2>=0.4 (from happybase->XX)
#   Obtaining dependency information for thriftpy2>=0.4 from https://files.pythonhosted.org/packages/5e/fd/4f7846bc25dd9935760a09bc37ae1d4523ebcb4678275da8d9eae09dd2a9/thriftpy2-0.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading thriftpy2-0.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (7.5 kB)
# Collecting importlib-resources (from happybase->XX)
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/8a/db/55a262f3606bebcae07cc14095338471ad7c0bbcaa37707e6f0ee49725b7/importlib_resources-7.1.0-py3-none-any.whl.metadata
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting lxml>=2.1 (from pyquery->XX)
#   Obtaining dependency information for lxml>=2.1 from https://files.pythonhosted.org/packages/31/ba/3c13d3fc24b7cacf675f808a3a1baabf43a30d0cd24c98f94548e9aa58eb/lxml-6.1.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading lxml-6.1.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Collecting cssselect>=1.2.0 (from pyquery->XX)
#   Obtaining dependency information for cssselect>=1.2.0 from https://files.pythonhosted.org/packages/20/0c/7bb51e3acfafd16c48875bf3db03607674df16f5b6ef8d056586af7e2b8b/cssselect-1.4.0-py3-none-any.whl.metadata
#   Downloading cssselect-1.4.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests->XX)
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/4b/f8/d0118a2f5f23b02cd166fa385c60f9b0d4f9194f574e2b31cef350ad7223/charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 827.0 kB/s eta 0:00:00a 0:00:01
# Collecting idna<4,>=2.5 (from requests->XX)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/5d/13/ad7d7ca3808a898b4612b6fe93cde56b53f3034dcde235acb1f0e1df24c6/idna-3.13-py3-none-any.whl.metadata
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests->XX)
#   Obtaining dependency information for urllib3<3,>=1.26 from https://files.pythonhosted.org/packages/39/08/aaaad47bc4e9dc8c725e68f9d04865dbcb2052843ff09c97b08904852d84/urllib3-2.6.3-py3-none-any.whl.metadata
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests->XX)
#   Obtaining dependency information for certifi>=2023.5.7 from https://files.pythonhosted.org/packages/22/30/7cd8fdcdfbc5b869528b079bfb76dcdf6056b1a2097a662e5e8c04f42965/certifi-2026.4.22-py3-none-any.whl.metadata
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting cryptography>=37.0.0 (from scrapy->XX)
#   Obtaining dependency information for cryptography>=37.0.0 from https://files.pythonhosted.org/packages/34/4f/e5711b28e1901f7d480a2b1b688b645aa4c77c73f10731ed17e7f7db3f0d/cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata
#   Downloading cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.5 kB)
# Collecting defusedxml>=0.7.1 (from scrapy->XX)
#   Obtaining dependency information for defusedxml>=0.7.1 from https://files.pythonhosted.org/packages/07/6c/aa3f2f849e01cb6a001cd8554a88d4c77c5c1a31c95bdf1cf9301e6d9ef4/defusedxml-0.7.1-py2.py3-none-any.whl.metadata
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting itemadapter>=0.1.0 (from scrapy->XX)
#   Obtaining dependency information for itemadapter>=0.1.0 from https://files.pythonhosted.org/packages/db/a6/48805cef65b13644f1c23545dc525a7051581c84f5227efb1cd9a8ac9b02/itemadapter-0.13.1-py3-none-any.whl.metadata
#   Downloading itemadapter-0.13.1-py3-none-any.whl.metadata (22 kB)
# Collecting itemloaders>=1.0.1 (from scrapy->XX)
#   Obtaining dependency information for itemloaders>=1.0.1 from https://files.pythonhosted.org/packages/ac/71/d9cd0e4c6a4aace991009fc47362ce9251be0fbcf2b6c533f918b31854d5/itemloaders-1.4.0-py3-none-any.whl.metadata
#   Downloading itemloaders-1.4.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: packaging in /workspaces/ds1001_final/ParkerLau_env/lib/python3.12/site-packages (from scrapy->XX) (26.2)
# Collecting parsel>=1.5.0 (from scrapy->XX)
#   Obtaining dependency information for parsel>=1.5.0 from https://files.pythonhosted.org/packages/08/23/4e0dae5e5bee14aea26dba003a682e621563451a20f751ed985810f818b6/parsel-1.11.0-py3-none-any.whl.metadata
#   Downloading parsel-1.11.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting protego>=0.1.15 (from scrapy->XX)
#   Obtaining dependency information for protego>=0.1.15 from https://files.pythonhosted.org/packages/d8/8c/f4dd590f48addf31398f78a78962eaa99eb4c87ac09c1927497032644731/protego-0.6.0-py3-none-any.whl.metadata
#   Downloading protego-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting pydispatcher>=2.0.5 (from scrapy->XX)
#   Obtaining dependency information for pydispatcher>=2.0.5 from https://files.pythonhosted.org/packages/66/0e/9ee7bc0b48ec45d93b302fa2d787830dca4dc454d31a237faa5815995988/PyDispatcher-2.0.7-py3-none-any.whl.metadata
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyopenssl>=22.0.0 (from scrapy->XX)
#   Obtaining dependency information for pyopenssl>=22.0.0 from https://files.pythonhosted.org/packages/a8/41/52f3a3e812b816a91e89aa504199d8bf989a1f873192b10762be66cf2009/pyopenssl-26.1.0-py3-none-any.whl.metadata
#   Downloading pyopenssl-26.1.0-py3-none-any.whl.metadata (19 kB)
# Collecting queuelib>=1.4.2 (from scrapy->XX)
#   Obtaining dependency information for queuelib>=1.4.2 from https://files.pythonhosted.org/packages/4a/1c/8df7b461497b42fcc1e7c44529201975ec77b0e1ebecd00df4b1f096c1d4/queuelib-1.9.0-py3-none-any.whl.metadata
#   Downloading queuelib-1.9.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting service-identity>=18.1.0 (from scrapy->XX)
#   Obtaining dependency information for service-identity>=18.1.0 from https://files.pythonhosted.org/packages/08/2c/ca6dd598b384bc1ce581e24aaae0f2bed4ccac57749d5c3befbb5e742081/service_identity-24.2.0-py3-none-any.whl.metadata
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tldextract (from scrapy->XX)
#   Obtaining dependency information for tldextract from https://files.pythonhosted.org/packages/6d/42/0e49d6d0aac449ca71952ec5bae764af009754fcb2e76a5cc097543747b3/tldextract-5.3.1-py3-none-any.whl.metadata
#   Downloading tldextract-5.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting twisted<=25.5.0,>=21.7.0 (from scrapy->XX)
#   Obtaining dependency information for twisted<=25.5.0,>=21.7.0 from https://files.pythonhosted.org/packages/eb/66/ab7efd8941f0bc7b2bd555b0f0471bff77df4c88e0cc31120c82737fec77/twisted-25.5.0-py3-none-any.whl.metadata
#   Downloading twisted-25.5.0-py3-none-any.whl.metadata (22 kB)
# Collecting w3lib>=1.17.0 (from scrapy->XX)
#   Obtaining dependency information for w3lib>=1.17.0 from https://files.pythonhosted.org/packages/66/c3/f8b216cbd742e5b84c40f045204c764ccb7524d2aeab021054ec69446b0a/w3lib-2.4.1-py3-none-any.whl.metadata
#   Downloading w3lib-2.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting zope-interface>=5.1.0 (from scrapy->XX)
#   Obtaining dependency information for zope-interface>=5.1.0 from https://files.pythonhosted.org/packages/53/5a/c4d52c58d5fee4ff67cc02f0dec24d0e84428520f67a52f1e4086f0e7779/zope_interface-8.4-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata
#   Downloading zope_interface-8.4-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 9.3 MB/s eta 0:00:00
# Collecting setuptools<81 (from scrapyd->XX)
#   Obtaining dependency information for setuptools<81 from https://files.pythonhosted.org/packages/94/b8/f1f62a5e3c0ad2ff1d189590bfa4c46b4f3b6e49cef6f26c6ee4e575394d/setuptools-80.10.2-py3-none-any.whl.metadata
#   Downloading setuptools-80.10.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pip in /workspaces/ds1001_final/ParkerLau_env/lib/python3.12/site-packages (from scrapyd-client->XX) (23.2.1)
# Collecting uberegg>=0.1.1 (from scrapyd-client->XX)
#   Obtaining dependency information for uberegg>=0.1.1 from https://files.pythonhosted.org/packages/44/f9/11d1c551c1957fdeef301653ddd8e8197a8088487185b815aa8a45ad3d97/uberegg-0.1.1-py3-none-any.whl.metadata
#   Downloading uberegg-0.1.1-py3-none-any.whl.metadata (658 bytes)
# Collecting greenlet>=1 (from sqlalchemy->XX)
#   Obtaining dependency information for greenlet>=1 from https://files.pythonhosted.org/packages/2b/e0/2e13df68f367e2f9960616927d60857dd7e56aaadd59a47c644216b2f920/greenlet-3.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading greenlet-3.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy->XX)
#   Obtaining dependency information for typing-extensions>=4.6.0 from https://files.pythonhosted.org/packages/18/67/36e9267722cc04a6b9f15c7f3441c2363321a3ea07da7ae0c0707beb2a9c/typing_extensions-4.15.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting cffi>=2.0.0 (from cryptography>=37.0.0->scrapy->XX)
#   Obtaining dependency information for cffi>=2.0.0 from https://files.pythonhosted.org/packages/78/2d/7fa73dfa841b5ac06c7b8855cfc18622132e365f5b81d02230333ff26e9e/cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy->XX)
#   Obtaining dependency information for jmespath>=0.9.5 from https://files.pythonhosted.org/packages/14/2f/967ba146e6d58cf6a652da73885f52fc68001525b4197effc174321d70b4/jmespath-1.1.0-py3-none-any.whl.metadata
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting attrs>=19.1.0 (from service-identity>=18.1.0->scrapy->XX)
#   Obtaining dependency information for attrs>=19.1.0 from https://files.pythonhosted.org/packages/64/b4/17d4b0b2a2dc85a6df63d1157e028ed19f90d4cd97c36717afef2bc2f395/attrs-26.1.0-py3-none-any.whl.metadata
#   Downloading attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting pyasn1 (from service-identity>=18.1.0->scrapy->XX)
#   Obtaining dependency information for pyasn1 from https://files.pythonhosted.org/packages/5d/a0/7d793dce3fa811fe047d6ae2431c672364b462850c6235ae306c0efd025f/pyasn1-0.6.3-py3-none-any.whl.metadata
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Collecting pyasn1-modules (from service-identity>=18.1.0->scrapy->XX)
#   Obtaining dependency information for pyasn1-modules from https://files.pythonhosted.org/packages/47/8d/d529b5d697919ba8c11ad626e835d4039be708a35b0d22de83a269a6682c/pyasn1_modules-0.4.2-py3-none-any.whl.metadata
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting ply<4.0,>=3.4 (from thriftpy2>=0.4->happybase->XX)
#   Obtaining dependency information for ply<4.0,>=3.4 from https://files.pythonhosted.org/packages/a3/58/35da89ee790598a0700ea49b2a66594140f44dec458c07e8e3d4979137fc/ply-3.11-py2.py3-none-any.whl.metadata
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting automat>=24.8.0 (from twisted<=25.5.0,>=21.7.0->scrapy->XX)
#   Obtaining dependency information for automat>=24.8.0 from https://files.pythonhosted.org/packages/02/ff/1175b0b7371e46244032d43a56862d0af455823b5280a50c63d99cc50f18/automat-25.4.16-py3-none-any.whl.metadata
#   Downloading automat-25.4.16-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from twisted<=25.5.0,>=21.7.0->scrapy->XX)
#   Obtaining dependency information for constantly>=15.1 from https://files.pythonhosted.org/packages/b8/40/c199d095151addf69efdb4b9ca3a4f20f70e20508d6222bffb9b76f58573/constantly-23.10.4-py3-none-any.whl.metadata
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from twisted<=25.5.0,>=21.7.0->scrapy->XX)
#   Obtaining dependency information for hyperlink>=17.1.1 from https://files.pythonhosted.org/packages/6e/aa/8caf6a0a3e62863cbb9dab27135660acba46903b703e224f14f447e57934/hyperlink-21.0.0-py2.py3-none-any.whl.metadata
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from twisted<=25.5.0,>=21.7.0->scrapy->XX)
#   Obtaining dependency information for incremental>=24.7.0 from https://files.pythonhosted.org/packages/1d/55/0f4df2a44053867ea9cbea73fc588b03c55605cd695cee0a3d86f0029cb2/incremental-24.11.0-py3-none-any.whl.metadata
#   Downloading incremental-24.11.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting requests-file>=1.4 (from tldextract->scrapy->XX)
#   Obtaining dependency information for requests-file>=1.4 from https://files.pythonhosted.org/packages/e1/d5/de8f089119205a09da657ed4784c584ede8381a0ce6821212a6d4ca47054/requests_file-3.0.1-py2.py3-none-any.whl.metadata
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting filelock>=3.0.8 (from tldextract->scrapy->XX)
#   Obtaining dependency information for filelock>=3.0.8 from https://files.pythonhosted.org/packages/81/47/dd9a212ef6e343a6857485ffe25bba537304f1913bdbed446a23f7f592e1/filelock-3.29.0-py3-none-any.whl.metadata
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=37.0.0->scrapy->XX)
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/0c/c3/44f3fbbfa403ea2a7c779186dc20772604442dde72947e7d01069cbe98e3/pycparser-3.0-py3-none-any.whl.metadata
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading XX-3.3.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 4.4 MB/s eta 0:00:00:00:01
# Downloading happybase-1.3.0-py2.py3-none-any.whl (26 kB)
# Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.6 MB/s eta 0:00:00
# Downloading pyquery-2.0.1-py3-none-any.whl (22 kB)
# Downloading redis-7.4.0-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 28.8 MB/s eta 0:00:00
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 13.5 MB/s eta 0:00:00
# Downloading scrapy-2.15.2-py3-none-any.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.9/352.9 kB 34.1 MB/s eta 0:00:00
# Downloading scrapy_redis-0.9.1-py2.py3-none-any.whl (18 kB)
# Downloading scrapyd-1.6.0-py3-none-any.whl (28 kB)
# Downloading scrapyd_client-2.0.3-py3-none-any.whl (13 kB)
# Downloading sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 40.6 MB/s eta 0:00:00:00:01
# Downloading tld-0.13.2-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 27.0 MB/s eta 0:00:00
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 877.1 kB/s eta 0:00:0000:01
# Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 25.6 MB/s eta 0:00:00
# Downloading cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 26.6 MB/s eta 0:00:0000:0100:01
# Downloading cssselect-1.4.0-py3-none-any.whl (18 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading greenlet-3.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.4/611.4 kB 2.9 MB/s eta 0:00:00:00:01
# Downloading idna-3.13-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 1.5 MB/s eta 0:00:00eta 0:00:01
# Downloading itemadapter-0.13.1-py3-none-any.whl (18 kB)
# Downloading itemloaders-1.4.0-py3-none-any.whl (12 kB)
# Downloading lxml-6.1.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 40.1 MB/s eta 0:00:00:00:0100:01
# Downloading parsel-1.11.0-py3-none-any.whl (14 kB)
# Downloading protego-0.6.0-py3-none-any.whl (10 kB)
# Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Downloading pyopenssl-26.1.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 7.5 MB/s eta 0:00:00
# Downloading queuelib-1.9.0-py3-none-any.whl (13 kB)
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading setuptools-80.10.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.3 MB/s eta 0:00:000:00:01
# Downloading thriftpy2-0.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 39.3 MB/s eta 0:00:00:00:01
# Downloading twisted-25.5.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.9 MB/s eta 0:00:00:00:01
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.6 MB/s eta 0:00:00
# Downloading uberegg-0.1.1-py3-none-any.whl (3.0 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 15.1 MB/s eta 0:00:00
# Downloading w3lib-2.4.1-py3-none-any.whl (21 kB)
# Downloading zope_interface-8.4-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 30.3 MB/s eta 0:00:00
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading tldextract-5.3.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 19.4 MB/s eta 0:00:00
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 2.1 MB/s eta 0:00:00
# Downloading automat-25.4.16-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 10.2 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 31.5 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 16.1 MB/s eta 0:00:00
# Downloading incremental-24.11.0-py3-none-any.whl (21 kB)
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 13.9 MB/s eta 0:00:00
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 4.4 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 21.4 MB/s eta 0:00:00
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: uberegg, pydispatcher, ply, logzero, zope-interface, w3lib, urllib3, typing-extensions, tld, thriftpy2, setuptools, redis, queuelib, pymysql, pycparser, pyasn1, protego, lxml, jmespath, itemadapter, incremental, importlib-resources, idna, greenlet, filelock, defusedxml, cssselect, constantly, charset_normalizer, certifi, automat, attrs, sqlalchemy, requests, pyquery, pyasn1-modules, parsel, hyperlink, happybase, cffi, twisted, requests-file, itemloaders, cryptography, tldextract, service-identity, pyopenssl, scrapy, scrapyd-client, scrapyd, scrapy-redis, XX
# Successfully installed XX-3.3.2 attrs-26.1.0 automat-25.4.16 certifi-2026.4.22 cffi-2.0.0 charset_normalizer-3.4.7 constantly-23.10.4 cryptography-47.0.0 cssselect-1.4.0 defusedxml-0.7.1 filelock-3.29.0 greenlet-3.5.0 happybase-1.3.0 hyperlink-21.0.0 idna-3.13 importlib-resources-7.1.0 incremental-24.11.0 itemadapter-0.13.1 itemloaders-1.4.0 jmespath-1.1.0 logzero-1.7.0 lxml-6.1.0 parsel-1.11.0 ply-3.11 protego-0.6.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 pydispatcher-2.0.7 pymysql-1.1.2 pyopenssl-26.1.0 pyquery-2.0.1 queuelib-1.9.0 redis-7.4.0 requests-2.33.1 requests-file-3.0.1 scrapy-2.15.2 scrapy-redis-0.9.1 scrapyd-1.6.0 scrapyd-client-2.0.3 service-identity-24.2.0 setuptools-80.10.2 sqlalchemy-2.0.49 thriftpy2-0.6.0 tld-0.13.2 tldextract-5.3.1 twisted-25.5.0 typing-extensions-4.15.0 uberegg-0.1.1 urllib3-2.6.3 w3lib-2.4.1 zope-interface-8.4
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Check !pip list again to confirm installations

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import fairlearn.metrics
from fairlearn.metrics import MetricFrame
from fairlearn.metrics import count, true_positive_rate, false_positive_rate, selection_rate, demographic_parity_ratio

# %% [markdown]
# ## Design: Data prep and exploration

# %%
bank_ds = pd.read_csv('/workspaces/ds1001_final/ds1001_final/data/processed/bank_final.csv') # the data is the data folder, 
#you'll need to use the correct path to the dataset. 

# How many rows are in the dataframe? How many columns?

# %%
# Explore the variables a bit more, create histograms for the numerics values and bar charts for the categorical.
# Histograms for numeric variables
numeric_columns = bank_ds.select_dtypes(include=['number']).columns
for col in numeric_columns: 
    plt.figure(figsize=(10, 6))
    sns.histplot(bank_ds[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

# %%
# Bar charts for categorical variables
categorical_columns = bank_ds.select_dtypes(include=['object', 'category']).columns
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=bank_ds[col])
    plt.title(f'Bar Chart of {col}')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipykernel_9264/295938107.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = bank_ds.select_dtypes(include=['object', 'category']).columns

# %%
# How many numeric columns are in the data set?
num_numeric_columns = bank_ds.select_dtypes(include=['number']).shape[1]

# %%
# Normalization
scaler = MinMaxScaler()
bank_ds[bank_ds.select_dtypes(include=['number']).columns] = scaler.fit_transform(bank_ds.select_dtypes(include=['number']))

# %%
# Likely need to convert categorical columns to category dtype
for col in bank_ds.select_dtypes(include=['object']).columns:
    bank_ds[col] = bank_ds[col].astype('category')
# Out:
# /tmp/ipykernel_9264/2784886216.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in bank_ds.select_dtypes(include=['object']).columns:

# %%
# Creating dummy variables, make sure the variables that need to be converted to dummies are categorical, not numeric.
# This might require you to convert some columns to categorical first using astype('category')
bank_ds = pd.get_dummies(bank_ds, drop_first=True)

# %%
# Display missing data using the isnull function, is there any missing data?
print(bank_ds.isnull().sum())
# Out:
# age                    0
# balance                0
# duration               0
# contactndays           0
# signed up              0
# job_blue-collar        0
# job_entrepreneur       0
# job_housemaid          0
# job_management         0
# job_retired            0
# job_self-employed      0
# job_services           0
# job_student            0
# job_technician         0
# job_unemployed         0
# job_unknown            0
# marital_married        0
# marital_single         0
# education_secondary    0
# education_tertiary     0
# education_unknown      0
# race_black             0
# race_hispanic          0
# race_white             0
# default_yes            0
# housing_yes            0
# contact_telephone      0
# contact_unknown        0
# gender_m               0
# dtype: int64

# %%
# remove missing values if needed
bank_ds = bank_ds.dropna()

# %%
# Scatterplot between two continuous variables
plt.figure(figsize=(10, 6))
sns.scatterplot(x='balance', y='duration', data=bank_ds)  # Replace 'Variable1' and 'Variable2' with your column names
plt.title('Scatterplot of Balance vs Duration')
plt.savefig('scatterplot.png')  # Save the scatterplot image
plt.show()

# %%
# Density chart of a continuous variable
plt.figure(figsize=(10, 6))
sns.kdeplot(bank_ds['balance'], fill=True)  # Replace 'ContinuousVariable' with your column name
plt.title('Density Chart of Balance')
plt.show()

# %%
#Correlation matrix, make sure to only include numeric variables
num_values = bank_ds.select_dtypes(include=['number'])
correlation_matrix = num_values.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Analytics: Build a model and Tune it for best Best Performance

# %%
# What is the ‘target’ of a model and what is the prevalence of the target in your dataset? Remember prevalence 
# is the proportion of records that take on the value of interest for the target variable, usually the positive class.
target_prevalence = bank_ds['signed up'].sum()  # Replace 'TargetVariable' with your target column name
print(f'Target Prevalence: {target_prevalence}')
# Out:
# Target Prevalence: 5074.0

# %%
# Divide the dataset into features and target
target = bank_ds['signed up']  # Replace 'TargetVariable' with your actual target column name and "xx" with your dataframe name
features = bank_ds.drop(columns=['signed up']) # Drop the target column from features

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Include your table for the 10 values of k you tried and the corresponding accuracies.

accuracy_results = {}

# Replace x with your desired range values, explain what is happening in this loop
for k in range(1,21,2 ):  
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train, y_train)
    accuracy = knn_model.score(X_test, y_test)
    accuracy_results[k] = accuracy
# Out:
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x79bd6f8704a0>
# Traceback (most recent call last):
#   File "/workspaces/ds1001_final/ParkerLau_env/lib/python3.12/site-packages/threadpoolctl.py", line 1005, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/workspaces/ds1001_final/ParkerLau_env/lib/python3.12/site-packages/threadpoolctl.py", line 1187, in _make_controller_from_path
#     lib_controller = controller_class(
#                      ^^^^^^^^^^^^^^^^^
#   File "/workspaces/ds1001_final/ParkerLau_env/lib/python3.12/site-packages/threadpoolctl.py", line 114, in __init__
#     self.dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/codespace/.python/current/lib/python3.12/ctypes/__init__.py", line 379, in __init__
#     self._handle = _dlopen(self._name, mode)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: /workspaces/ds1001_final/ParkerLau_env/lib/python3.12/site-packages/scipy.libs/libscipy_openblas-6cdc3b4a.so: cannot open shared object file: No such file or directory

# %%
#graph of accuracy vs k values
plt.figure(figsize=(10, 6))
plt.plot(list(accuracy_results.keys()), list(accuracy_results.values()), marker='o')
plt.title('KNN Accuracy vs K Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.xticks(list(accuracy_results.keys()))
plt.grid()
plt.show()

# %%
# using the hyperparameter k that gave the best accuracy, rerun the model and generate 
# predictions on the test set. Explain why you choose this k value.
best_k = 9  # Replace 'xx' with the best k value found
knn_model = KNeighborsClassifier(n_neighbors=best_k)
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)

# %% [markdown]
# ## Value: Evaluation and Protected Classes

# %%
# create a confusion matrix for your model's predictions. 
# What does the confusion matrix tell you about your model's performance?
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %%
#We already have a model above using KNN so we can use the results to compute fairness metrics

# Compute fairness metrics using Fairlearn

my_metrics = {
    'true positive rate' : true_positive_rate,
    'false positive rate' : false_positive_rate,
    'selection rate' : selection_rate,
    'count' : count
}
# Construct a MetricFrame for race
mf_race = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test["race_black"]  # Replace with your first protected class
)

# Construct a MetricFrame for gender
mf_gender = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test["gender_m"]  # Replace second protected class 
)

# %%
mf_race.by_group #What do the results show? Change the mf_race with each subgroup and report the findings. This means
# you should run this cell multiple times, once for each of the levels in the race variable.
# Out:
#             true positive rate  false positive rate  selection rate   count
# race_black
# False                 0.076060             0.010152        0.018266  6515.0
# True                  0.099138             0.007580        0.017187  2211.0

# %%
mf_gender.by_group #What do the results show? There's only two groups here so we don't need to change anything. 
# in the metric frame.
# Out:
#           true positive rate  false positive rate  selection rate   count
# gender_m
# False               0.073874             0.010537        0.018616  4351.0
# True                0.089770             0.008470        0.017371  4375.0

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# two fairness ratios using the gender_m feature, which is bi-variate. What do the results show, is the model more or 
# less fair with this grouping?

dpr_gender = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Demographic Parity ratio:\t", dpr_gender)

eodds_gender = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Equalized Odds ratio:\t\t", eodds_gender)
# Out:
# Demographic Parity ratio:	 0.9331245149911817
# Equalized Odds ratio:		 0.8038244353182752

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# the same features above only using a filtered search to pull in all the possibilities of features
# starting with "race". What do the results show, is the model more or less fair with this grouping?

dpr_race = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Demographic Parity ratio:\t", dpr_race)

eodds_race = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Equalized Odds ratio:\t\t", eodds_race)
# Out:
# Demographic Parity ratio:	 0.7515133323327831
# Equalized Odds ratio:		 0.6497772061187927

# %%
#Optional code to add, commit, and push changes to your GitHub repository
# !git add .
# !git commit -m "Insert Message Here" # This will commit your changes to git. 
# !git push # This will push your changes to back to your remote repository on GitHub.
# Out:
# [main 40d21f5] Insert Message Here
#  2 files changed, 795 insertions(+), 71 deletions(-)
#  create mode 100644 ds1001_final/notebooks/scatterplot.png
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 479.62 KiB | 14.53 MiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/parkerjlau/ds1001_final
#    dc46059..40d21f5  main -> main
